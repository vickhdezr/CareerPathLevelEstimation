# %%
import logging
logging.basicConfig(format='%(asctime)s : %(levelname)s : %(message)s', level=logging.INFO)
import os
import tempfile
import numpy as np
import pandas as pd
import csv
import string
import json
import tensorflow as tf
import pickle
import copy

from sklearn.cluster import DBSCAN
from sklearn import metrics
from sklearn.decomposition import PCA

import matplotlib.pyplot as plt

# %% [markdown]
# ## Analysis of skills using word2vec embedding

# %%
fpath= os.getcwd()
fprepath= os.path.join(fpath,"Preprocessing/")
file = open(os.path.join(fprepath,"JobSkillEmbbyword_sep.p"),"rb")
# file = open(os.path.join(fprepath,"jobSkillD2V_sep.p"),"rb")
JobSentenceEmb = pickle.load(file)

# %%
JobSentenceEmb[0][2]
# Out:
# [['python'],
#  ['c++'],
#  ['opengl'],
#  ['computer_vision'],
#  ['algorithms'],
#  ['computer_science'],
#  ['machine_learning'],
#  ['data_analysis'],
#  ['data_visualization'],
#  ['software_design'],
#  ['science'],
#  ['computer_graphics'],
#  ['3d_visualization'],
#  ['big_data'],
#  ['object_oriented_design'],
#  ['shell_scripting'],
#  ['web_services'],
#  ['climate_change'],
#  ['web_development'],
#  ['proposal_writing'],
#  ['social_media'],
#  ['java'],
#  ['javascript'],
#  ['jquery_ui'],
#  ['jquery'],
#  ['android'],
#  ['high_performance_computing'],
#  ['parallel_computing'],
#  ['vtk'],
#  ['scientific_computing'],
#  ['cmake'],
#  ['mpi'],
#  ['qt'],
#  ['virtual_reality'],
#  ['opengl_es'],
#  ['data_science'],
#  ['geoprocessing'],
#  ['geovisualization'],
#  ['paraview'],
#  ['gdal'],
#  ['webgl'],
#  ['geographic_information_science'],
#  ['scientific_data_management'],
#  ['data_analytics'],
#  ['big_data_analytics'],
#  ['unix_shell_scripting']]

# %%
pmSentences= []
for jse in JobSentenceEmb:
    if jse[0].find("project manager or equivalent")!= -1 and jse[0].find("senior project manager or equivalent")== -1:
        pmSentences.append(jse[0:4])

jsenemb=[]
jsenskill=[]
for js in pmSentences:
    for tkn in js[3]:
        jsenemb.append(tkn)  
    for tk in js[2]:
        jsenskill.append(tk)

print ('Total Sentences: {}'.format(len(jsenemb)))
# Out:
# Total Sentences: 2076

# %%
minSamples=[12]#[6,12,50,120]
eps = [0.75]#[0.80,0.81]#[0.3,0.5,0.75]

jsenemb = np.asarray(jsenemb)
mets = ['cosine','canberra','hamming']#'euclidean'#'cosine'
# #############################################################################
# Compute DBSCAN
for met in mets:
    print('Metric: %s' %met)
    for ep in eps:
        print('Eps: {}'.format(ep))
        for minsample in minSamples:
            dbscan_model = DBSCAN(eps=ep, min_samples=minsample,metric=met)
            x = dbscan_model.fit(jsenemb)
            core_samples_mask = np.zeros_like(dbscan_model.labels_, dtype=bool)
            core_samples_mask[dbscan_model.core_sample_indices_] = True
            labels = dbscan_model.labels_

        # Number of clusters in labels, ignoring noise if present.
            n_clusters_ = len(set(labels)) - (1 if -1 in labels else 0)
            n_noise_ = list(labels).count(-1)

            print('Min Samples: {}'.format(minsample))
            print('Estimated number of clusters: %d' % n_clusters_)
            print('Estimated number of noise points: %d' % n_noise_)
            
            #Calculation of Principal Component analysis
            pca = PCA(n_components=2).fit(jsenemb)
            datapoint = pca.transform(jsenemb)

            # Plot result
            # Black removed and is used for noise instead.
            unique_labels = set(labels)
            colors = [plt.cm.Spectral(each)
                      for each in np.linspace(0, 1, len(unique_labels))]
            print(len(colors))
            for k, col in zip(unique_labels, colors):
                if k == -1:
                    # Black used for noise.
                    col = [0, 0, 0, 1]

                class_member_mask = (labels == k)

                xy = datapoint[class_member_mask & core_samples_mask]
                plt.plot(xy[:, 0], xy[:, 1], 'o', markerfacecolor=tuple(col),
                         markeredgecolor='k', markersize=12)

                xy = datapoint[class_member_mask & ~core_samples_mask]
                plt.plot(xy[:, 0], xy[:, 1], '.', markerfacecolor=tuple(col),
                         markeredgecolor='k', markersize=2)

#             plt.margins(x=0, y=-0.45)   # Values in (-0.5, 0.0) zooms in to center

            plt.title('Estimated number of clusters: {} - {}'.format(n_clusters_,met))
            plt.show()
# Out:
# Metric: cosine
# Eps: 0.75
# Min Samples: 12
# Estimated number of clusters: 25
# Estimated number of noise points: 1611
# 26
# Metric: canberra
# Eps: 0.75
# Min Samples: 12
# Estimated number of clusters: 23
# Estimated number of noise points: 1659
# 24
# Metric: hamming
# Eps: 0.75
# Min Samples: 12
# Estimated number of clusters: 23
# Estimated number of noise points: 1659
# 24

# %%
#Print lables and skills
len(labels)
for l in range(len(labels)):
    print("{}*{}*{}".format(l,jsenskill[l],labels[l]))
# Out:
# 0*['python']*-1
# 1*['c++']*-1
# 2*['opengl']*-1
# 3*['computer_vision']*-1
# 4*['algorithms']*-1
# 5*['computer_science']*-1
# 6*['machine_learning']*-1
# 7*['data_analysis']*-1
# 8*['data_visualization']*-1
# 9*['software_design']*-1
# 10*['science']*-1
# 11*['computer_graphics']*-1
# 12*['3d_visualization']*-1
# 13*['big_data']*-1
# 14*['object_oriented_design']*-1
# 15*['shell_scripting']*-1
# 16*['web_services']*-1
# 17*['climate_change']*-1
# 18*['web_development']*-1
# 19*['proposal_writing']*-1
# 20*['social_media']*-1
# 21*['java']*-1
# 22*['javascript']*-1
# 23*['jquery_ui']*-1
# 24*['jquery']*-1
# 25*['android']*-1
# 26*['high_performance_computing']*-1
# 27*['parallel_computing']*-1
# 28*['vtk']*-1
# 29*['scientific_computing']*-1
# 30*['cmake']*-1
# 31*['mpi']*-1
# 32*['qt']*-1
# 33*['virtual_reality']*-1
# 34*['opengl_es']*-1
# 35*['data_science']*-1
# 36*['geoprocessing']*-1
# 37*['geovisualization']*-1
# 38*['paraview']*-1
# 39*['gdal']*-1
# 40*['webgl']*-1
# 41*['geographic_information_science']*-1
# 42*['scientific_data_management']*-1
# 43*['data_analytics']*-1
# 44*['big_data_analytics']*-1
# 45*['unix_shell_scripting']*-1
# 46*['troubleshooting']*-1
# 47*['security']*-1
# 48*['software_installation']*-1
# 49*['electronics']*-1
# 50*['testing']*-1
# 51*['technical_support']*-1
# 52*['software_documentation']*-1
# 53*['maintenance_', '_repair']*-1
# 54*['dod']*-1
# 55*['telecommunications']*-1
# 56*['system_administration']*-1
# 57*['integration']*0
# 58*['system_deployment']*-1
# 59*['video']*-1
# 60*['systems_engineering']*-1
# 61*['network_administration']*-1
# 62*['cabling']*-1
# 63*['network_security']*-1
# 64*['security+']*-1
# 65*['wireless_networking']*-1
# 66*['computer_security']*-1
# 67*['calibration']*-1
# 68*['wireless']*-1
# 69*['soldering']*-1
# 70*['help_desk_support']*-1
# 71*['field_service']*-1
# 72*['printers']*-1
# 73*['vpn']*-1
# 74*['data_center']*-1
# 75*['voip']*-1
# 76*['lan-wan']*-1
# 77*['firewalls']*-1
# 78*['hardware']*-1
# 79*['test_equipment']*-1
# 80*['computer_hardware']*-1
# 81*['servers']*-1
# 82*['windows_7']*-1
# 83*['operating_systems']*-1
# 84*['cisco_technologies']*-1
# 85*['windows_server']*-1
# 86*['switches']*-1
# 87*['xp']*-1
# 88*['windows']*-1
# 89*['routers']*-1
# 90*['networking']*-1
# 91*['security_clearance']*-1
# 92*['install']*-1
# 93*['structures']*-1
# 94*['wiring']*-1
# 95*['java']*-1
# 96*['sql']*1
# 97*['enterprise_architecture']*-1
# 98*['project_management']*2
# 99*['data_management']*-1
# 100*['pmbok']*-1
# 101*['javascript']*-1
# 102*['microsoft_office']*3
# 103*['oracle_database']*-1
# 104*['microsoft_sql_server']*-1
# 105*['sharepoint']*-1
# 106*['linux']*-1
# 107*['html']*4
# 108*['d3.js']*-1
# 109*['sybase']*-1
# 110*['microsoft_project_server']*-1
# 111*['togaf']*-1
# 112*['sharepoint_designer']*-1
# 113*['data_visualizations']*-1
# 114*['archimate']*-1
# 115*['dama']*-1
# 116*['team_leadership']*5
# 117*['project_planning']*-1
# 118*['change_management']*6
# 119*['epc']*-1
# 120*['project_engineering']*-1
# 121*['engineering']*-1
# 122*['contract_management']*-1
# 123*['construction']*-1
# 124*['petrochemical']*-1
# 125*['refinery']*-1
# 126*['procurement']*-1
# 127*['project_control']*-1
# 128*['piping']*-1
# 129*['oil_', '_gas']*-1
# 130*['construction_management']*-1
# 131*['energy']*-1
# 132*['project_estimation']*-1
# 133*['p', 'id']*-1
# 134*['cost_control']*-1
# 135*['autocad']*-1
# 136*['distributed_team_management']*-1
# 137*['team_building']*-1
# 138*['contract_negotiation']*-1
# 139*['process_piping_design']*-1
# 140*['leadership']*7
# 141*['feed']*-1
# 142*['refinery_operations']*-1
# 143*['gestión_of_proyectos_of_software']*-1
# 144*['análisis_of_negocio']*-1
# 145*['java']*-1
# 146*['project_management']*2
# 147*['pmp']*-1
# 148*['business_intelligence']*8
# 149*['software_development']*9
# 150*['information_technologies_management']*-1
# 151*['html']*4
# 152*['bases_of_datos']*-1
# 153*['microsoft_office']*3
# 154*['management']*10
# 155*['sales']*-1
# 156*['marketing']*-1
# 157*['social_media']*-1
# 158*['project_management']*2
# 159*['account_management']*-1
# 160*['marketing_strategy']*-1
# 161*['inventory_management']*-1
# 162*['sales_management']*-1
# 163*['office_administration']*-1
# 164*['strategic_planning']*-1
# 165*['social_networking']*-1
# 166*['crm']*-1
# 167*['finance']*-1
# 168*['research']*-1
# 169*['manage_client_relationships']*-1
# 170*['product_development']*-1
# 171*['portfolio_management']*-1
# 172*['human_resources']*-1
# 173*['retail']*-1
# 174*['credit']*-1
# 175*['business_development']*-1
# 176*['international_project_management']*-1
# 177*['project_planning']*-1
# 178*['microsoft_excel']*-1
# 179*['microsoft_word']*-1
# 180*['powerpoint']*-1
# 181*['microsoft_powerpoint']*-1
# 182*['time_management']*-1
# 183*['customer_service']*11
# 184*['teamwork']*-1
# 185*['team_building']*-1
# 186*['cross-functional_team_leadership']*-1
# 187*['public_speaking']*-1
# 188*['leadership']*7
# 189*['employee_management']*-1
# 190*['customer_relationship_management_', 'crm']*-1
# 191*['recruiting']*-1
# 192*['airline_booking_engine', 'travel_technology_solutions']*-1
# 193*['seo']*-1
# 194*['performance_management']*-1
# 195*['crm']*-1
# 196*['online_marketing']*-1
# 197*['hr_consulting']*-1
# 198*['business_development']*-1
# 199*['change_management']*6
# 200*['travel']*-1
# 201*['travel_management']*-1
# 202*['talent_acquisition']*-1
# 203*['microsoft_office']*3
# 204*['microsoft_excel']*-1
# 205*['html']*4
# 206*['css']*-1
# 207*['microsoft_word']*-1
# 208*['javascript']*-1
# 209*['google_analytics']*-1
# 210*['hris']*-1
# 211*['team_management']*-1
# 212*['management']*10
# 213*['customer_service']*11
# 214*['sourcing']*-1
# 215*['talent_management']*-1
# 216*['team_leadership']*5
# 217*['employee_relations']*-1
# 218*['search']*-1
# 219*['air_booking_engine']*-1
# 220*['flight_booking_engine']*-1
# 221*['hotel_booking_engine']*-1
# 222*['technology_solutions_for_travel']*-1
# 223*['travel_booking_engines_system']*-1
# 224*['travel_technology_services']*-1
# 225*['travel_technology_company']*-1
# 226*['airline_booking_engine_for_travel_agents']*-1
# 227*['b2b_travel_services']*-1
# 228*['flights_booking_engine']*-1
# 229*['airline_ticketing_systems']*-1
# 230*['travel_agency_booking_engine']*-1
# 231*['air_booking_engine']*-1
# 232*['b2c_booking_engine_services']*-1
# 233*['b2b_booking_engine_services']*-1
# 234*['itil']*-1
# 235*['data_center']*-1
# 236*['it_service_management']*-1
# 237*['project_management']*2
# 238*['virtualization']*-1
# 239*['information_technology']*-1
# 240*['infrastructure']*-1
# 241*['it_management']*-1
# 242*['pmo']*-1
# 243*['pre-sales']*-1
# 244*['firewalls']*-1
# 245*['telecommunications']*-1
# 246*['vpn']*-1
# 247*['technical_support']*-1
# 248*['integration']*0
# 249*['network_architecture']*-1
# 250*['pmp']*-1
# 251*['disaster_recovery']*-1
# 252*['storage']*-1
# 253*['troubleshooting']*-1
# 254*['wireless_networking']*-1
# 255*['it_operations']*-1
# 256*['san']*-1
# 257*['cluster']*-1
# 258*['project_portfolio_management']*-1
# 259*['cloud_computing']*-1
# 260*['business_process']*12
# 261*['system_deployment']*-1
# 262*['windows_server']*-1
# 263*['active_directory']*-1
# 264*['servers']*-1
# 265*['databases']*-1
# 266*['vmware_esx']*-1
# 267*['operating_systems']*-1
# 268*['linux']*-1
# 269*['hardware']*-1
# 270*['windows']*-1
# 271*['microsoft_exchange']*-1
# 272*['citrix']*-1
# 273*['routers']*-1
# 274*['sql']*1
# 275*['team_leadership']*5
# 276*['management']*10
# 277*['networking']*-1
# 278*['terminal_server']*-1
# 279*['citrix_metaframe']*-1
# 280*['enterprise_storage']*-1
# 281*['enterprise_backup']*-1
# 282*['storage_area_networks']*-1
# 283*['virtualization_technology']*-1
# 284*['project_management']*2
# 285*['software_project_management']*13
# 286*['business_analysis']*14
# 287*['requirements_analysis']*15
# 288*['sdlc']*-1
# 289*['crm']*-1
# 290*['strategy']*-1
# 291*['pmp']*-1
# 292*['it_strategy']*-1
# 293*['it_management']*-1
# 294*['project_portfolio_management']*-1
# 295*['analysis']*-1
# 296*['pmo']*-1
# 297*['it_service_management']*-1
# 298*['agile_methodologies']*16
# 299*['integration']*0
# 300*['vendor_management']*17
# 301*['it_operations']*-1
# 302*['software_development_life_cycle_', 'sdlc']*-1
# 303*['sql']*1
# 304*['ms_project']*-1
# 305*['management']*10
# 306*['leadership']*7
# 307*['hp_quality_center']*-1
# 308*['scrum']*18
# 309*['test_management']*-1
# 310*['manual_testing']*-1
# 311*['agile_testing']*-1
# 312*['agile_methodologies']*16
# 313*['test_planning']*-1
# 314*['test_strategy']*-1
# 315*['functional_testing']*-1
# 316*['istqb']*-1
# 317*['testing']*-1
# 318*['cmmi']*-1
# 319*['test_cases']*-1
# 320*['regression_testing']*-1
# 321*['extract', '_transform', '_load_', 'etl']*-1
# 322*['system_testing']*-1
# 323*['banking']*-1
# 324*['agile_project_management']*19
# 325*['software_quality_assurance']*-1
# 326*['quality_center']*-1
# 327*['hp_qtp']*-1
# 328*['sql']*1
# 329*['microsoft_sql_server']*-1
# 330*['test_execution']*-1
# 331*['integration_testing']*-1
# 332*['system_integration_testing']*-1
# 333*['rally']*-1
# 334*['black_box_testing']*-1
# 335*['e2e']*-1
# 336*['datastage']*-1
# 337*['billing_systems']*-1
# 338*['software_testing_life_cycle_', 'stlc']*-1
# 339*['test_cases']*-1
# 340*['regression_test']*-1
# 341*['microsoft_sql_server']*-1
# 342*['databases']*-1
# 343*['agile_project_management']*19
# 344*['software_project_management']*13
# 345*['software_development']*9
# 346*['agile_methodologies']*16
# 347*['business_intelligence']*8
# 348*['pmp']*-1
# 349*['cmmi']*-1
# 350*['scrum']*18
# 351*['web_applications']*-1
# 352*['automation']*-1
# 353*['risk_management']*-1
# 354*['web_development']*-1
# 355*['quality_management']*-1
# 356*['c', '#']*-1
# 357*['sql']*1
# 358*['.net']*-1
# 359*['ms_project']*-1
# 360*['uml']*-1
# 361*['tfs']*-1
# 362*['visual_studio']*-1
# 363*['iis']*-1
# 364*['tableau']*-1
# 365*['power_bi']*-1
# 366*['r']*-1
# 367*['python']*-1
# 368*['leadership']*7
# 369*['teamwork']*-1
# 370*['cransoft']*-1
# 371*['capacity_planning']*-1
# 372*['data_science']*-1
# 373*['jquery']*-1
# 374*['c', '#']*-1
# 375*['html']*4
# 376*['project_management']*2
# 377*['scrum']*18
# 378*['strategic_planning']*-1
# 379*['agile_methodologies']*16
# 380*['microsoft_sql_server']*-1
# 381*['.net']*-1
# 382*['sql']*1
# 383*['asp.net']*-1
# 384*['xml']*-1
# 385*['jira']*-1
# 386*['css']*-1
# 387*['java']*-1
# 388*['javascript']*-1
# 389*['mysql']*-1
# 390*['crystal_reports']*-1
# 391*['magento']*-1
# 392*['team_management']*-1
# 393*['waterfall_project_management']*-1
# 394*['software_development']*9
# 395*['software_design']*-1
# 396*['microsoft_html5_with_javascript_and_css3']*-1
# 397*['business_analysis']*14
# 398*['accounting']*-1
# 399*['forecasting']*-1
# 400*['finance']*-1
# 401*['financial_analysis']*-1
# 402*['business_process_improvement']*20
# 403*['retail']*-1
# 404*['requirements_analysis']*15
# 405*['sdlc']*-1
# 406*['agile_project_management']*19
# 407*['requirements_gathering']*-1
# 408*['scrum']*18
# 409*['process_improvement']*-1
# 410*['business_requirements']*-1
# 411*['financial_reporting']*-1
# 412*['internal_controls']*-1
# 413*['gaap']*-1
# 414*['agile_methodologies']*16
# 415*['sales']*-1
# 416*['strategic_sourcing']*-1
# 417*['financial_accounting']*-1
# 418*['data_analysis']*-1
# 419*['agile']*-1
# 420*['it_solutions']*-1
# 421*['it_strategy']*-1
# 422*['business_strategy']*-1
# 423*['software_documentation']*-1
# 424*['sap']*-1
# 425*['pos']*-1
# 426*['enterprise_software']*-1
# 427*['interpersonal_skills']*-1
# 428*['business_relationship_management']*-1
# 429*['training']*21
# 430*['customer_service']*11
# 431*['team_building']*-1
# 432*['professional_networking']*-1
# 433*['business_networking']*-1
# 434*['p', 'l']*-1
# 435*['sprint_planning']*-1
# 436*['retail_software']*-1
# 437*['java']*-1
# 438*['web_services']*-1
# 439*['sql']*1
# 440*['industry_knowledge', '_']*-1
# 441*['agile_methodologies']*16
# 442*['android_development']*-1
# 443*['agile']*-1
# 444*['programming']*-1
# 445*['javascript']*-1
# 446*['html']*4
# 447*['mysql']*-1
# 448*['subversion']*-1
# 449*['apache']*-1
# 450*['jsp']*-1
# 451*['linux']*-1
# 452*['perl']*-1
# 453*['struts']*-1
# 454*['databases']*-1
# 455*['c++']*-1
# 456*['sql_server']*-1
# 457*['php']*-1
# 458*['j2ee']*-1
# 459*['tomcat']*-1
# 460*['xml']*-1
# 461*['android_sdk']*-1
# 462*['c']*-1
# 463*['unix']*-1
# 464*['eclipse']*-1
# 465*['servlets']*-1
# 466*['operating_systems']*-1
# 467*['docker']*-1
# 468*['django']*-1
# 469*['ios']*-1
# 470*['hbase']*-1
# 471*['hadoop']*-1
# 472*['git']*-1
# 473*['android_studio']*-1
# 474*['rational_software_architect']*-1
# 475*['rational_team_concert']*-1
# 476*['dropwizard']*-1
# 477*['microservices']*-1
# 478*['global_team_work']*-1
# 479*['swagger']*-1
# 480*['requirements_analysis']*15
# 481*['sdlc']*-1
# 482*['business_intelligence']*8
# 483*['software_project_management']*13
# 484*['requirements_gathering']*-1
# 485*['business_analysis']*14
# 486*['software_development']*9
# 487*['it_strategy']*-1
# 488*['change_management']*6
# 489*['crm']*-1
# 490*['process_improvement']*-1
# 491*['software_development_life_cycle_', 'sdlc']*-1
# 492*['testing']*-1
# 493*['release_management']*-1
# 494*['analytical_skills']*-1
# 495*['software_engineering']*-1
# 496*['project_estimation']*-1
# 497*['project_coordination']*-1
# 498*['java_enterprise_edition']*-1
# 499*['microsoft_sql_server']*-1
# 500*['java']*-1
# 501*['pl/sql']*-1
# 502*['jsp']*-1
# 503*['outsourcing']*-1
# 504*['project_implementation']*-1
# 505*['troubleshooting']*-1
# 506*['project_management']*2
# 507*['risk_assessment']*-1
# 508*['restructuring']*-1
# 509*['process_re-engineering']*-1
# 510*['managed_services']*-1
# 511*['pre-sales']*-1
# 512*['business_process_re-engineering']*-1
# 513*['crm']*-1
# 514*['employer_branding']*-1
# 515*['contract_recruitment']*-1
# 516*['pricing']*-1
# 517*['vendor_management']*17
# 518*['integration']*0
# 519*['performance_management']*-1
# 520*['business_strategy']*-1
# 521*['strategy']*-1
# 522*['recruiting']*-1
# 523*['sales']*-1
# 524*['human_resources']*-1
# 525*['project_planning']*-1
# 526*['telecommunications']*-1
# 527*['business_process']*12
# 528*['resource_management']*-1
# 529*['change_management']*6
# 530*['sales_operations']*-1
# 531*['technical_recruiting']*-1
# 532*['consulting']*-1
# 533*['permanent_placement']*-1
# 534*['business_intelligence']*8
# 535*['executive_search']*-1
# 536*['screening_resumes']*-1
# 537*['leadership']*7
# 538*['contract_negotiation']*-1
# 539*['negotiation']*-1
# 540*['strategic_partnerships']*-1
# 541*['sourcing']*-1
# 542*['management']*10
# 543*['talent_management']*-1
# 544*['solution_implementation']*-1
# 545*['full_lifecycle_rpo']*-1
# 546*['operational_turnaround']*-1
# 547*['value_re-engineering']*-1
# 548*['technology_implementation']*-1
# 549*['financials']*-1
# 550*['restructure']*-1
# 551*['new_business_development']*-1
# 552*['rpo']*-1
# 553*['sourcing']*-1
# 554*['recruiting']*-1
# 555*['temporary_placement']*-1
# 556*['human_resources']*-1
# 557*['staffing_services']*-1
# 558*['vendor_management']*17
# 559*['technical_recruiting']*-1
# 560*['employee_benefits']*-1
# 561*['internet_recruiting']*-1
# 562*['technical_support']*-1
# 563*['benefits_negotiation']*-1
# 564*['contract_recruitment']*-1
# 565*['screening_resumes']*-1
# 566*['screening']*-1
# 567*['executive_search']*-1
# 568*['onboarding']*-1
# 569*['temporary_staffing']*-1
# 570*['permanent_placement']*-1
# 571*['applicant_tracking_systems']*-1
# 572*['management']*10
# 573*['leadership']*7
# 574*['interviews']*-1
# 575*['talent_management']*-1
# 576*['employee_relations']*-1
# 577*['training']*21
# 578*['networking']*-1
# 579*['talent_acquisition']*-1
# 580*['awesomeness']*-1
# 581*['microsoft_sql_server']*-1
# 582*['software_development']*9
# 583*['.net']*-1
# 584*['project_management']*2
# 585*['business_planning']*-1
# 586*['product_management']*-1
# 587*['scrum']*18
# 588*['strategy']*-1
# 589*['entrepreneurship']*-1
# 590*['research']*-1
# 591*['web_development']*-1
# 592*['analytics']*-1
# 593*['management_consulting']*-1
# 594*['virtualization']*-1
# 595*['outsourcing']*-1
# 596*['web_services']*-1
# 597*['continuous_integration']*-1
# 598*['cloud_computing']*-1
# 599*['databases']*-1
# 600*['xml']*-1
# 601*['oracle']*-1
# 602*['sql']*1
# 603*['c', '#']*-1
# 604*['javascript']*-1
# 605*['mysql']*-1
# 606*['visual_basic']*-1
# 607*['jquery']*-1
# 608*['php']*-1
# 609*['crystal_reports']*-1
# 610*['html']*4
# 611*['css']*-1
# 612*['ajax']*-1
# 613*['cms']*-1
# 614*['cobol']*-1
# 615*['asp.net_mvc']*-1
# 616*['windows_azure']*-1
# 617*['c/c++']*-1
# 618*['team_management']*-1
# 619*['problem_solving']*-1
# 620*['thought_leadership']*-1
# 621*['business_modeling']*-1
# 622*['technology_start-up']*-1
# 623*['strategic_architecture']*-1
# 624*['symfony']*-1
# 625*['installshield']*-1
# 626*['msbuild']*-1
# 627*['software_licensing']*-1
# 628*['api']*-1
# 629*['new_business_development']*-1
# 630*['mvc']*-1
# 631*['software_project_management']*13
# 632*['requirements_analysis']*15
# 633*['sdlc']*-1
# 634*['it_strategy']*-1
# 635*['global_delivery']*-1
# 636*['business_analysis']*14
# 637*['agile_methodologies']*16
# 638*['pmp']*-1
# 639*['solution_architecture']*-1
# 640*['pre-sales']*-1
# 641*['software_development']*9
# 642*['soa']*-1
# 643*['software_quality_assurance']*-1
# 644*['data_warehousing']*-1
# 645*['project_management']*2
# 646*['cmmi']*-1
# 647*['etl']*-1
# 648*['data_modeling']*-1
# 649*['oracle']*-1
# 650*['pl/sql']*-1
# 651*['waterfall']*-1
# 652*['iam']*-1
# 653*['requirements_analysis']*15
# 654*['sql']*1
# 655*['oracle']*-1
# 656*['agile_methodologies']*16
# 657*['data_warehousing']*-1
# 658*['software_development']*9
# 659*['software_development_life_cycle_', 'sdlc']*-1
# 660*['software_project_management']*13
# 661*['risk_analysis']*-1
# 662*['root_cause_analysis']*-1
# 663*['change_management']*6
# 664*['problem_management']*-1
# 665*['user_acceptance_testing']*-1
# 666*['regression_testing']*-1
# 667*['business_intelligence']*8
# 668*['unix']*-1
# 669*['informatica']*-1
# 670*['xml']*-1
# 671*['db2']*-1
# 672*['business_objects']*-1
# 673*['xcelsius']*-1
# 674*['perl']*-1
# 675*['performance_appraisal']*-1
# 676*['team_building']*-1
# 677*['oracle_warehouse_builder']*-1
# 678*['software_cost_estimation']*-1
# 679*['presenting_proposals']*-1
# 680*['proposal_preparation']*-1
# 681*['business_objects_data_services']*-1
# 682*['effort_estimation']*-1
# 683*['technical_hiring']*-1
# 684*['data_analysis']*-1
# 685*['user_experience']*-1
# 686*['product_requirement_definition']*-1
# 687*['agile_project_management']*19
# 688*['business_development']*-1
# 689*['scrum']*18
# 690*['product_management']*-1
# 691*['product_development']*-1
# 692*['product_design']*-1
# 693*['mobile_applications']*-1
# 694*['e-commerce']*-1
# 695*['marketing_strategy']*-1
# 696*['project_management']*2
# 697*['agile_methodologies']*16
# 698*['marketing']*-1
# 699*['advertising']*-1
# 700*['web_development']*-1
# 701*['user_experience_design']*-1
# 702*['rapid_prototyping']*-1
# 703*['business_strategy']*-1
# 704*['user_interface_design']*-1
# 705*['start-ups']*-1
# 706*['strategy']*-1
# 707*['software_development_life_cycle_', 'sdlc']*-1
# 708*['program_management']*22
# 709*['software_project_management']*13
# 710*['business_analysis']*14
# 711*['html']*4
# 712*['css']*-1
# 713*['jira']*-1
# 714*['microsoft_office']*3
# 715*['microsoft_excel']*-1
# 716*['leadership']*7
# 717*['mentoring']*-1
# 718*['management']*10
# 719*['cross-functional_team_leadership']*-1
# 720*['client_services']*-1
# 721*['user_experience_testing']*-1
# 722*['e-commerce_consulting']*-1
# 723*['mobile_application_development']*-1
# 724*['confluence']*-1
# 725*['oracle']*-1
# 726*['pl/sql']*-1
# 727*['databases']*-1
# 728*['sdlc']*-1
# 729*['requirements_analysis']*15
# 730*['vendor_management']*17
# 731*['etl']*-1
# 732*['screening']*-1
# 733*['benefits_negotiation']*-1
# 734*['data_modeling']*-1
# 735*['agile_methodologies']*16
# 736*['business_analysis']*14
# 737*['testing']*-1
# 738*['user_acceptance_testing']*-1
# 739*['programming']*-1
# 740*['data_migration']*-1
# 741*['microsoft_sql_server']*-1
# 742*['sql']*1
# 743*['unix']*-1
# 744*['visio']*-1
# 745*['xml']*-1
# 746*['visual_basic']*-1
# 747*['crystal_reports']*-1
# 748*['db2']*-1
# 749*['solaris']*-1
# 750*['html']*4
# 751*['sharepoint']*-1
# 752*['uml']*-1
# 753*['java']*-1
# 754*['asp.net']*-1
# 755*['t-sql']*-1
# 756*['ms_project']*-1
# 757*['windows']*-1
# 758*['core_java']*-1
# 759*['relational_databases']*-1
# 760*['linux']*-1
# 761*['business_objects']*-1
# 762*['oracle_applications']*-1
# 763*['asp']*-1
# 764*['vbscript']*-1
# 765*['perl']*-1
# 766*['access']*-1
# 767*['mysql']*-1
# 768*['c++']*-1
# 769*['business_intelligence_tools']*-1
# 770*['oracle_reports']*-1
# 771*['erwin']*-1
# 772*['sql*plus']*-1
# 773*['sql_tuning']*-1
# 774*['unix_shell_scripting']*-1
# 775*['microsoft_sql_server']*-1
# 776*['sql']*1
# 777*['.net']*-1
# 778*['erp']*-1
# 779*['itil']*-1
# 780*['business_intelligence']*8
# 781*['systems_analysis']*-1
# 782*['scrum']*18
# 783*['pmbok']*-1
# 784*['cobit']*-1
# 785*['project_management']*2
# 786*['asp.net']*-1
# 787*['oracle']*-1
# 788*['vb.net']*-1
# 789*['asp']*-1
# 790*['c', '#']*-1
# 791*['visio']*-1
# 792*['uml']*-1
# 793*['mysql']*-1
# 794*['microsoft_project']*-1
# 795*['ms_project']*-1
# 796*['.net_framework']*-1
# 797*['dreamweaver']*-1
# 798*['visual_basic_.net_', 'vb.net']*-1
# 799*['rup']*-1
# 800*['informix']*-1
# 801*['bpmn']*-1
# 802*['pmi']*-1
# 803*['agile_methodologies']*16
# 804*['quality_assurance_management']*-1
# 805*['product_management']*-1
# 806*['test_automation']*-1
# 807*['software_development']*9
# 808*['testing']*-1
# 809*['scrum']*18
# 810*['sdlc']*-1
# 811*['software_engineering']*-1
# 812*['scalability']*-1
# 813*['distributed_systems']*-1
# 814*['business_intelligence']*8
# 815*['cloud_computing']*-1
# 816*['integration']*0
# 817*['web_applications']*-1
# 818*['test_planning']*-1
# 819*['software_documentation']*-1
# 820*['business_analysis']*14
# 821*['accounting_and_finance']*-1
# 822*['requirements_analysis']*15
# 823*['software_quality_assurance']*-1
# 824*['project_management']*2
# 825*['business-to-business_', 'b2b']*-1
# 826*['linux']*-1
# 827*['sql']*1
# 828*['java']*-1
# 829*['oracle']*-1
# 830*['databases']*-1
# 831*['enterprise_software']*-1
# 832*['xml']*-1
# 833*['postgresql']*-1
# 834*['saas']*-1
# 835*['mysql']*-1
# 836*['selenium']*-1
# 837*['jira']*-1
# 838*['windows']*-1
# 839*['unix']*-1
# 840*['python']*-1
# 841*['junit']*-1
# 842*['vmware']*-1
# 843*['amazon_web_services_', 'aws']*-1
# 844*['leadership']*7
# 845*['mentoring']*-1
# 846*['training']*21
# 847*['storage_management']*-1
# 848*['enterprise_storage']*-1
# 849*['jmeter']*-1
# 850*['zoho_crm']*-1
# 851*['confluence']*-1
# 852*['user_acceptane_testing_', 'uat']*-1
# 853*['project_management']*2
# 854*['erp']*-1
# 855*['business_process']*12
# 856*['business_analysis']*14
# 857*['business_intelligence']*8
# 858*['pmp']*-1
# 859*['it_management']*-1
# 860*['business_process_improvement']*20
# 861*['change_management']*6
# 862*['management_consulting']*-1
# 863*['itil']*-1
# 864*['cmmi']*-1
# 865*['software_development']*9
# 866*['team_leadership']*5
# 867*['sistemas_de_planificación_de_recursos_empresariales']*-1
# 868*['análisis_de_negocio']*-1
# 869*['procesos_de_negocio']*-1
# 870*['gestión_de_proyectos']*-1
# 871*['consultoría']*-1
# 872*['liderazgo_de_equipos']*-1
# 873*['inteligencia_empresarial']*-1
# 874*['consultoría_de_estrategia_y_operaciones']*-1
# 875*['administración_de_las_tecnologías_de_la_información']*-1
# 876*['certificación_pmp']*-1
# 877*['jde_manufacturing']*-1
# 878*['jde_distribution']*-1
# 879*['estrategia_ti']*-1
# 880*['estrategia']*-1
# 881*['mejora_de_procesos_de_negocio']*-1
# 882*['jde_scm']*-1
# 883*['development']*-1
# 884*['social_media']*-1
# 885*['social_media_marketing']*-1
# 886*['public_speaking']*-1
# 887*['nsales_operations']*-1
# 888*['public_relations']*-1
# 889*['product_management']*-1
# 890*['sales']*-1
# 891*['marketing']*-1
# 892*['broadcast_television']*-1
# 893*['journalism']*-1
# 894*['sports_marketing']*-1
# 895*['business_development']*-1
# 896*['event_planning']*-1
# 897*['microsoft_excel']*-1
# 898*['powerpoint']*-1
# 899*['facebook']*-1
# 900*['microsoft_office']*3
# 901*['microsoft_word']*-1
# 902*['ntelephone_skills']*-1
# 903*['team_leadership']*5
# 904*['customer_service']*11
# 905*['leadership']*7
# 906*['time_management']*-1
# 907*['sports_writing']*-1
# 908*['new_business_development']*-1
# 909*['networking']*-1
# 910*['organizational_behavior']*-1
# 911*['inside_sales']*-1
# 912*['social_networking']*-1
# 913*['business_analyst']*-1
# 914*['systems_analyst']*-1
# 915*['project_management']*2
# 916*['program_management']*22
# 917*['recruiting']*-1
# 918*['sales']*-1
# 919*['account_management']*-1
# 920*['human_resources']*-1
# 921*['technical_recruiting']*-1
# 922*['sales_operations']*-1
# 923*['customer_retention']*-1
# 924*['employee_benefits']*-1
# 925*['college_recruiting']*-1
# 926*['strategic_planning']*-1
# 927*['business_development']*-1
# 928*['analysis']*-1
# 929*['customer_satisfaction']*-1
# 930*['telecommunications']*-1
# 931*['market_research']*-1
# 932*['process_improvement']*-1
# 933*['hiring']*-1
# 934*['temporary_placement']*-1
# 935*['executive_search']*-1
# 936*['applicant_tracking_systems']*-1
# 937*['salesforce.com']*-1
# 938*['microsoft_office']*3
# 939*['visio']*-1
# 940*['sharepoint']*-1
# 941*['leadership']*7
# 942*['management']*10
# 943*['personnel_management']*-1
# 944*['career_counseling']*-1
# 945*['customer_service']*11
# 946*['interviews']*-1
# 947*['training']*21
# 948*['employee_relations']*-1
# 949*['cold_calling']*-1
# 950*['career_development']*-1
# 951*['staff_development']*-1
# 952*['leadership_development']*-1
# 953*['talent_acquisition']*-1
# 954*['networking']*-1
# 955*['selling']*-1
# 956*['technical_recruiter']*-1
# 957*['finance_', '_accounting_recruiter']*-1
# 958*['program_management']*22
# 959*['business_transformation']*-1
# 960*['stakeholder_management']*-1
# 961*['outsourcing']*-1
# 962*['project_delivery']*-1
# 963*['managed_services']*-1
# 964*['telecommunications']*-1
# 965*['change_management']*6
# 966*['business_process_improvement']*20
# 967*['service_delivery']*-1
# 968*['public_sector']*-1
# 969*['business_analysis']*14
# 970*['business_strategy']*-1
# 971*['strategic_planning']*-1
# 972*['professional_services']*-1
# 973*['solution_selling']*-1
# 974*['cloud_computing']*-1
# 975*['account_management']*-1
# 976*['business_development']*-1
# 977*['organizational_design']*-1
# 978*['business_process']*12
# 979*['resource_management']*-1
# 980*['business_planning']*-1
# 981*['contract_management']*-1
# 982*['vendor_management']*17
# 983*['risk_management']*-1
# 984*['it_strategy']*-1
# 985*['digital_strategy']*-1
# 986*['customer_relationship_management_', 'crm']*-1
# 987*['agile_project_management']*19
# 988*['oracle_e-business_suite']*-1
# 989*['management']*10
# 990*['contract_negotiation']*-1
# 991*['team_leadership']*5
# 992*['people_management']*-1
# 993*['stakeholder_engagement']*-1
# 994*['culture_change']*-1
# 995*['leadership']*7
# 996*['partner_management']*-1
# 997*['programme_delivery']*-1
# 998*['benefits_realisation']*-1
# 999*['proposition_development']*-1
# 1000*['business_case']*-1
# 1001*['governance']*-1
# 1002*['strategy_development']*-1
# 1003*['financial_management_experience']*-1
# 1004*['nhs']*-1
# 1005*['central_government']*-1
# 1006*['non-executive_director']*-1
# 1007*['waterfall_project_management']*-1
# 1008*['strategic_planning']*-1
# 1009*['research']*-1
# 1010*['analyst']*-1
# 1011*['microsoft_office']*3
# 1012*['microsoft_excel']*-1
# 1013*['microsoft_powerpoint']*-1
# 1014*['team_leadership']*5
# 1015*['salesforce.com']*-1
# 1016*['microsoft_dynamics_crm']*-1
# 1017*['agile_', '_waterfall_methodologies']*-1
# 1018*['business_analysis']*14
# 1019*['business_requirements']*-1
# 1020*['business_process']*12
# 1021*['user_acceptance_testing']*-1
# 1022*['system_testing']*-1
# 1023*['analytical_skills']*-1
# 1024*['business_process_improvement']*20
# 1025*['accounting']*-1
# 1026*['account_reconciliation']*-1
# 1027*['customer_relationship_management_', 'crm']*-1
# 1028*['jira']*-1
# 1029*['microsoft_excel']*-1
# 1030*['microsoft_powerpoint']*-1
# 1031*['powerpoint']*-1
# 1032*['stakeholder_management']*-1
# 1033*['management']*10
# 1034*['time_management']*-1
# 1035*['training']*21
# 1036*['collaborative_problem_solving']*-1
# 1037*['team_leadership']*5
# 1038*['communication']*-1
# 1039*['teamwork']*-1
# 1040*['regulation']*-1
# 1041*['hp_application_lifecycle_management']*-1
# 1042*['project_life_cycle']*-1
# 1043*['psd2']*-1
# 1044*['gdpr']*-1
# 1045*['user_stories']*-1
# 1046*['business_impact_analysis']*-1
# 1047*['requirements_traceability']*-1
# 1048*['microsoft_visual_studio_c++']*-1
# 1049*['confluence']*-1
# 1050*['collaboration']*-1
# 1051*['business_analysis\\project_management\\software_project_management']*-1
# 1052*['software_development']*9
# 1053*['erp']*-1
# 1054*['pmo']*-1
# 1055*['strategy']*-1
# 1056*['integration']*0
# 1057*['agile_methodologies']*16
# 1058*['risk_management']*-1
# 1059*['cloud_computing']*-1
# 1060*['cmmi']*-1
# 1061*['scrum']*18
# 1062*['business_intelligence']*8
# 1063*['microsoft_office']*3
# 1064*['salesforce.com']*-1
# 1065*['management']*10
# 1066*['team_leadership']*5
# 1067*['teamwork']*-1
# 1068*['time_management']*-1
# 1069*['leadership']*7
# 1070*['ca_clarity']*-1
# 1071*['rally']*-1
# 1072*['multicultural']*-1
# 1073*['ca_agile_central']*-1
# 1074*['java']*-1
# 1075*['front-end_development']*-1
# 1076*['back-end_web_development']*-1
# 1077*['web_development']*-1
# 1078*['project_management_office_', 'pmo']*-1
# 1079*['automation']*-1
# 1080*['ui']*-1
# 1081*['data_warehousing']*-1
# 1082*['html5']*-1
# 1083*['technical_leadership']*-1
# 1084*['data_science']*-1
# 1085*['agile_leadership']*-1
# 1086*['big_data_analytics']*-1
# 1087*['front-end_coding']*-1
# 1088*['ux']*-1
# 1089*['project_management']*2
# 1090*['prince2']*-1
# 1091*['consulting']*-1
# 1092*['outsourcing']*-1
# 1093*['strategy']*-1
# 1094*['human_resources']*-1
# 1095*['recruiting']*-1
# 1096*['contract_recruitment']*-1
# 1097*['it_recruitment']*-1
# 1098*['temporary_placement']*-1
# 1099*['screening']*-1
# 1100*['executive_search']*-1
# 1101*['temporary_staffing']*-1
# 1102*['recruitment_advertising']*-1
# 1103*['permanent_placement']*-1
# 1104*['strategic_sourcing']*-1
# 1105*['technical_recruiting']*-1
# 1106*['resource_management']*-1
# 1107*['screening_resumes']*-1
# 1108*['graduate_recruitment']*-1
# 1109*['sales']*-1
# 1110*['internet_recruiting']*-1
# 1111*['employer_branding']*-1
# 1112*['benefits_negotiation']*-1
# 1113*['applicant_tracking_systems']*-1
# 1114*['stakeholder_management']*-1
# 1115*['management']*10
# 1116*['team_leadership']*5
# 1117*['sourcing']*-1
# 1118*['training']*21
# 1119*['team_building']*-1
# 1120*['team_management']*-1
# 1121*['interviews']*-1
# 1122*['talent_management']*-1
# 1123*['human_relationship']*-1
# 1124*['talent_acquisition']*-1
# 1125*['candidate_generation']*-1
# 1126*['networking']*-1
# 1127*['rpo']*-1
# 1128*['software_development']*9
# 1129*['project_management']*2
# 1130*['business_analysis']*14
# 1131*['integration']*0
# 1132*['project_delivery']*-1
# 1133*['systems_analysis']*-1
# 1134*['project_implementation']*-1
# 1135*['sdlc']*-1
# 1136*['vendor_management']*17
# 1137*['resource_management']*-1
# 1138*['business_requirements']*-1
# 1139*['service_delivery']*-1
# 1140*['system_deployment']*-1
# 1141*['requirements_analysis']*15
# 1142*['user_acceptance_testing']*-1
# 1143*['software_project_management']*13
# 1144*['test_planning']*-1
# 1145*['it_strategy']*-1
# 1146*['it_service_management']*-1
# 1147*['pmp']*-1
# 1148*['architecture']*-1
# 1149*['requirements_gathering']*-1
# 1150*['solution_architecture']*-1
# 1151*['itil']*-1
# 1152*['project_portfolio_management']*-1
# 1153*['business_process']*12
# 1154*['databases']*-1
# 1155*['microsoft_sql_server']*-1
# 1156*['db2']*-1
# 1157*['sharepoint']*-1
# 1158*['xml']*-1
# 1159*['cobol']*-1
# 1160*['visual_basic']*-1
# 1161*['java']*-1
# 1162*['javascript']*-1
# 1163*['.net']*-1
# 1164*['sap']*-1
# 1165*['sql']*1
# 1166*['oracle']*-1
# 1167*['html']*4
# 1168*['jcl']*-1
# 1169*['css']*-1
# 1170*['microsoft_office']*3
# 1171*['sharepoint']*-1
# 1172*['information_technology']*-1
# 1173*['technical_support']*-1
# 1174*['project_management']*2
# 1175*['testing']*-1
# 1176*['software_documentation']*-1
# 1177*['software_installation']*-1
# 1178*['troubleshooting']*-1
# 1179*['system_deployment']*-1
# 1180*['system_administration']*-1
# 1181*['windows_7']*-1
# 1182*['windows_xp']*-1
# 1183*['visio']*-1
# 1184*['computer_hardware']*-1
# 1185*['microsoft_project']*-1
# 1186*['operating_systems']*-1
# 1187*['xp']*-1
# 1188*['hardware']*-1
# 1189*['windows']*-1
# 1190*['vmware']*-1
# 1191*['os_x']*-1
# 1192*['active_directory']*-1
# 1193*['microsoft_access']*-1
# 1194*['lotus_notes']*-1
# 1195*['mac_os_x']*-1
# 1196*['ms_project']*-1
# 1197*['microsoft_visio']*-1
# 1198*['customer_service']*11
# 1199*['answering_phones']*-1
# 1200*['networking']*-1
# 1201*['ibm_tivoli']*-1
# 1202*['hardware_installation']*-1
# 1203*['vmware_workstation']*-1
# 1204*['vmware_fusion']*-1
# 1205*['life_cycle_assessment']*-1
# 1206*['ca_clarity']*-1
# 1207*['determination_to_succeed']*-1
# 1208*['organization']*-1
# 1209*['internet']*-1
# 1210*['close_attention_to_detail']*-1
# 1211*['fast_learner']*-1
# 1212*['project_management']*2
# 1213*['vendor_management']*17
# 1214*['leadership']*7
# 1215*['strategy']*-1
# 1216*['consulting']*-1
# 1217*['it_strategy']*-1
# 1218*['program_management']*22
# 1219*['it_management']*-1
# 1220*['change_management']*6
# 1221*['outsourcing']*-1
# 1222*['business_process_improvement']*20
# 1223*['analysis']*-1
# 1224*['it_service_management']*-1
# 1225*['crm']*-1
# 1226*['system_administration']*-1
# 1227*['integration']*0
# 1228*['databases']*-1
# 1229*['tableau']*-1
# 1230*['management']*10
# 1231*['training']*21
# 1232*['coaching']*-1
# 1233*['intercultural_training']*-1
# 1234*['telecommunications']*-1
# 1235*['security']*-1
# 1236*['fitness_training']*-1
# 1237*['project_management']*2
# 1238*['satellite_communications_', 'satcom']*-1
# 1239*['operational_planning']*-1
# 1240*['itil_certified']*-1
# 1241*['prince2']*-1
# 1242*['agile_project_management']*19
# 1243*['lean_six_sigma']*-1
# 1244*['program_management']*22
# 1245*['project_management_body_of_knowledge_', 'pmbok']*-1
# 1246*['risk_management']*-1
# 1247*['quality', '_health', '_safety', '_and_environment_', 'qhse']*-1
# 1248*['identity_', '_access_management_', 'iam']*-1
# 1249*['microsoft_project']*-1
# 1250*['microsoft_office']*3
# 1251*['training_delivery']*-1
# 1252*['team_leadership']*5
# 1253*['training']*21
# 1254*['organizational_leadership']*-1
# 1255*['mentoring']*-1
# 1256*['communication']*-1
# 1257*['bowman']*-1
# 1258*['prince_practitioner']*-1
# 1259*['subcontractor_supervision']*-1
# 1260*['supplier_management']*-1
# 1261*['sailpoint']*-1
# 1262*['strategic_manan']*-1
# 1263*['project_management']*2
# 1264*['management']*10
# 1265*['leadership']*7
# 1266*['strategy']*-1
# 1267*['process_improvement']*-1
# 1268*['strategic_planning']*-1
# 1269*['consulting']*-1
# 1270*['business_analysis']*14
# 1271*['change_management']*6
# 1272*['e-commerce']*-1
# 1273*['marketing_strategy']*-1
# 1274*['program_management']*22
# 1275*['project_portfolio_management']*-1
# 1276*['vendor_management']*17
# 1277*['product_development']*-1
# 1278*['business_process_improvement']*20
# 1279*['budgets']*-1
# 1280*['integrated_marketing']*-1
# 1281*['requirements_analysis']*15
# 1282*['web_design']*-1
# 1283*['web_analytics']*-1
# 1284*['product_marketing']*-1
# 1285*['digital_marketing']*-1
# 1286*['data_analysis']*-1
# 1287*['retail']*-1
# 1288*['project_planning']*-1
# 1289*['web_development']*-1
# 1290*['interactive_marketing']*-1
# 1291*['event_management']*-1
# 1292*['agile_project_management']*19
# 1293*['public_relations']*-1
# 1294*['brand_management']*-1
# 1295*['project_coordination']*-1
# 1296*['business_planning']*-1
# 1297*['software']*-1
# 1298*['business_process_re-engineering']*-1
# 1299*['web_project_management']*-1
# 1300*['account_management']*-1
# 1301*['software_project_management']*13
# 1302*['analytics']*-1
# 1303*['microsoft_office']*3
# 1304*['html']*4
# 1305*['ms_project']*-1
# 1306*['cross-functional_team_leadership']*-1
# 1307*['negotiation']*-1
# 1308*['contract_negotiation']*-1
# 1309*['team_leadership']*5
# 1310*['strategic_thinking']*-1
# 1311*['customer_engagement']*-1
# 1312*['custom_software']*-1
# 1313*['management']*10
# 1314*['project_management']*2
# 1315*['microsoft_office']*3
# 1316*['business_strategy']*-1
# 1317*['mobile_devices']*-1
# 1318*['business_development']*-1
# 1319*['operations_management']*-1
# 1320*['business_analysis']*14
# 1321*['product_management']*-1
# 1322*['business_intelligence']*8
# 1323*['business_process_improvement']*20
# 1324*['social_media']*-1
# 1325*['mysql']*-1
# 1326*['html']*4
# 1327*['microsoft_excel']*-1
# 1328*['cascading_style_sheets_', 'css']*-1
# 1329*['sql']*1
# 1330*['team_leadership']*5
# 1331*['leadership']*7
# 1332*['customer_service']*11
# 1333*['teamwork']*-1
# 1334*['notification']*-1
# 1335*['new_business_development']*-1
# 1336*['project_management']*2
# 1337*['information_assurance']*-1
# 1338*['project_planning']*-1
# 1339*['information_technology']*-1
# 1340*['program_management']*22
# 1341*['project_delivery']*-1
# 1342*['risk_management']*-1
# 1343*['change_management']*6
# 1344*['business_analysis']*14
# 1345*['requirements_analysis']*15
# 1346*['business_process_improvement']*20
# 1347*['vendor_management']*17
# 1348*['project_engineering']*-1
# 1349*['project_implementation']*-1
# 1350*['human_resources']*-1
# 1351*['data_analysis']*-1
# 1352*['hr_policies']*-1
# 1353*['workplace_safety']*-1
# 1354*['environment', '_health', '_and_safety_', 'ehs']*-1
# 1355*['military_logistics']*-1
# 1356*['project_coordination']*-1
# 1357*['computer_network_operations']*-1
# 1358*['military_training']*-1
# 1359*['military_operations']*-1
# 1360*['environmental_compliance']*-1
# 1361*['management']*10
# 1362*['stakeholder_management']*-1
# 1363*['customer_service']*11
# 1364*['presentation_skills']*-1
# 1365*['client_liaison']*-1
# 1366*['people_management']*-1
# 1367*['people_development']*-1
# 1368*['driver_training']*-1
# 1369*['developed_vetting']*-1
# 1370*['chauffeur']*-1
# 1371*['cyber_defense']*-1
# 1372*['cyber_warfare']*-1
# 1373*['cyber_operations']*-1
# 1374*['engaging_people']*-1
# 1375*['hr_project_management']*-1
# 1376*['military_weapons_handling']*-1
# 1377*['military_leadership']*-1
# 1378*['joint_military_operations']*-1
# 1379*['ministry_of_defence']*-1
# 1380*['security_clearance']*-1
# 1381*['driver_hgv']*-1
# 1382*['cyber-security']*-1
# 1383*['accounting']*-1
# 1384*['business_planning']*-1
# 1385*['business_ethics']*-1
# 1386*['logistics_management']*-1
# 1387*['risk_management']*-1
# 1388*['corporate_social_responsibility']*-1
# 1389*['investments']*-1
# 1390*['banking']*-1
# 1391*['telemarketing']*-1
# 1392*['digital_marketing']*-1
# 1393*['social_media_marketing']*-1
# 1394*['innovation_management']*-1
# 1395*['negotiation']*-1
# 1396*['strategic_enterprise_management']*-1
# 1397*['relationship_management']*-1
# 1398*['creative_solutions']*-1
# 1399*['project_management']*2
# 1400*['strategic_planning']*-1
# 1401*['professional_services']*-1
# 1402*['event_planning']*-1
# 1403*['b2b']*-1
# 1404*['nonprofits']*-1
# 1405*['clinical_research']*-1
# 1406*['psychology']*-1
# 1407*['social_media']*-1
# 1408*['public_relations']*-1
# 1409*['marketing']*-1
# 1410*['sales']*-1
# 1411*['marketing_strategy']*-1
# 1412*['adobe_creative_suite']*-1
# 1413*['microsoft_office']*3
# 1414*['leadership']*7
# 1415*['team_building']*-1
# 1416*['management']*10
# 1417*['training']*21
# 1418*['coaching']*-1
# 1419*['public_speaking']*-1
# 1420*['customer_service']*11
# 1421*['strategic_alliances']*-1
# 1422*['growth_opportunities']*-1
# 1423*['behavioral_therapy_', 'aba']*-1
# 1424*['organizational_communication']*-1
# 1425*['social_networking']*-1
# 1426*['vendor_relationship_management']*-1
# 1427*['business_analysis']*14
# 1428*['project_management']*2
# 1429*['business_intelligence']*8
# 1430*['integration']*0
# 1431*['erp']*-1
# 1432*['project_delivery']*-1
# 1433*['business_process']*12
# 1434*['change_management']*6
# 1435*['requirements_analysis']*15
# 1436*['business_process_improvement']*20
# 1437*['software_project_management']*13
# 1438*['it_management']*-1
# 1439*['pre-sales']*-1
# 1440*['project_portfolio_management']*-1
# 1441*['it_strategy']*-1
# 1442*['professional_services']*-1
# 1443*['project_planning']*-1
# 1444*['crm']*-1
# 1445*['software_development']*9
# 1446*['cloud_computing']*-1
# 1447*['software_implementation']*-1
# 1448*['prince2']*-1
# 1449*['data_migration']*-1
# 1450*['process_improvement']*-1
# 1451*['enterprise_resource_planning_', 'erp']*-1
# 1452*['software_documentation']*-1
# 1453*['business_transformation']*-1
# 1454*['risk_management']*-1
# 1455*['systems_analysis']*-1
# 1456*['customer_relationship_management_', 'crm']*-1
# 1457*['enterprise_software']*-1
# 1458*['microsoft_sql_server']*-1
# 1459*['databases']*-1
# 1460*['sql']*1
# 1461*['saas']*-1
# 1462*['ms_project']*-1
# 1463*['microsoft_project']*-1
# 1464*['management']*10
# 1465*['stakeholder_management']*-1
# 1466*['team_management']*-1
# 1467*['training']*21
# 1468*['negotiation']*-1
# 1469*['problem_solving']*-1
# 1470*['governance']*-1
# 1471*['leadership']*7
# 1472*['cold_calling']*-1
# 1473*['training']*21
# 1474*['customer_retention']*-1
# 1475*['crm']*-1
# 1476*['sales_operations']*-1
# 1477*['recruiting']*-1
# 1478*['sales']*-1
# 1479*['account_management']*-1
# 1480*['case_managment']*-1
# 1481*['event_planning']*-1
# 1482*['it_solutions']*-1
# 1483*['social_media']*-1
# 1484*['marketing']*-1
# 1485*['technical_recruiting']*-1
# 1486*['project_management']*2
# 1487*['salesforce.com']*-1
# 1488*['google_analytics']*-1
# 1489*['sap']*-1
# 1490*['outlook']*-1
# 1491*['microsoft_office']*3
# 1492*['powerpoint']*-1
# 1493*['microsoft_excel']*-1
# 1494*['saas']*-1
# 1495*['microsoft_word']*-1
# 1496*['applicant_tracking_systems']*-1
# 1497*['public_speaking']*-1
# 1498*['time_management']*-1
# 1499*['team_leadership']*5
# 1500*['lead_generation']*-1
# 1501*['building_relationships']*-1
# 1502*['customer_service']*11
# 1503*['management']*10
# 1504*['interviews']*-1
# 1505*['sourcing']*-1
# 1506*['windows_', '_mac_operating_systems']*-1
# 1507*['social_networking']*-1
# 1508*['full-life_cycle_recruiting']*-1
# 1509*['project_delivery']*-1
# 1510*['it_service_management']*-1
# 1511*['data_center']*-1
# 1512*['infrastructure']*-1
# 1513*['project_management']*2
# 1514*['virtualization']*-1
# 1515*['telecommunications']*-1
# 1516*['prince2']*-1
# 1517*['project_portfolio_management']*-1
# 1518*['itil']*-1
# 1519*['resource_management']*-1
# 1520*['service_delivery']*-1
# 1521*['it_management']*-1
# 1522*['outsourcing']*-1
# 1523*['change_management']*6
# 1524*['firewalls']*-1
# 1525*['vendor_management']*17
# 1526*['integration']*0
# 1527*['it_strategy']*-1
# 1528*['pmo']*-1
# 1529*['it_operations']*-1
# 1530*['business_analysis']*14
# 1531*['cabling']*-1
# 1532*['managed_services']*-1
# 1533*['program_management']*22
# 1534*['pre-sales']*-1
# 1535*['business_process_improvement']*20
# 1536*['requirements_analysis']*15
# 1537*['software_project_management']*13
# 1538*['security']*-1
# 1539*['cloud_computing']*-1
# 1540*['agile_project_management']*19
# 1541*['enterprise_architecture']*-1
# 1542*['business_intelligence']*8
# 1543*['business_process']*12
# 1544*['solution_architecture']*-1
# 1545*['disaster_recovery']*-1
# 1546*['it_outsourcing']*-1
# 1547*['sdlc']*-1
# 1548*['switches']*-1
# 1549*['management']*10
# 1550*['team_building']*-1
# 1551*['team_leadership']*5
# 1552*['stakeholder_management']*-1
# 1553*['leadership']*7
# 1554*['networking']*-1
# 1555*['project_team_building']*-1
# 1556*['governance']*-1
# 1557*['service_management']*-1
# 1558*['teamwork']*-1
# 1559*['information_technology']*-1
# 1560*['time_management']*-1
# 1561*['research']*-1
# 1562*['analysis']*-1
# 1563*['microsoft_word']*-1
# 1564*['powerpoint']*-1
# 1565*['customer_service']*11
# 1566*['team_leadership']*5
# 1567*['team_spirit']*-1
# 1568*['commercial_awareness']*-1
# 1569*['articulate']*-1
# 1570*['social_networking']*-1
# 1571*['project_management']*2
# 1572*['strategy']*-1
# 1573*['management']*10
# 1574*['business_strategy']*-1
# 1575*['change_management']*6
# 1576*['public_sector']*-1
# 1577*['account_management']*-1
# 1578*['business_development']*-1
# 1579*['business_process_improvement']*20
# 1580*['customer_service']*11
# 1581*['leadership']*7
# 1582*['team_leadership']*5
# 1583*['stakeholder_management']*-1
# 1584*['networking']*-1
# 1585*['new_business_development']*-1
# 1586*['business_analysis']*14
# 1587*['analysis']*-1
# 1588*['sdlc']*-1
# 1589*['project_management']*2
# 1590*['business_requirements']*-1
# 1591*['vendor_management']*17
# 1592*['financial_services']*-1
# 1593*['it_management']*-1
# 1594*['banking']*-1
# 1595*['requirements_analysis']*15
# 1596*['requirements_gathering']*-1
# 1597*['data_analysis']*-1
# 1598*['software_documentation']*-1
# 1599*['business_process_improvement']*20
# 1600*['risk_management']*-1
# 1601*['pmo']*-1
# 1602*['agile_methodologies']*16
# 1603*['product_management']*-1
# 1604*['analytics']*-1
# 1605*['portfolio_management']*-1
# 1606*['process_improvement']*-1
# 1607*['software_project_management']*13
# 1608*['project_planning']*-1
# 1609*['fixed_income']*-1
# 1610*['integration']*0
# 1611*['it_strategy']*-1
# 1612*['business_intelligence']*8
# 1613*['quality_assurance']*-1
# 1614*['crm']*-1
# 1615*['business_process']*12
# 1616*['securities']*-1
# 1617*['systems_analysis']*-1
# 1618*['user_acceptance_testing']*-1
# 1619*['project_portfolio_management']*-1
# 1620*['equities']*-1
# 1621*['change_management']*6
# 1622*['product_development']*-1
# 1623*['testing']*-1
# 1624*['agile_project_management']*19
# 1625*['visio']*-1
# 1626*['business_objects']*-1
# 1627*['ms_project']*-1
# 1628*['sharepoint']*-1
# 1629*['sap']*-1
# 1630*['management']*10
# 1631*['leadership']*7
# 1632*['team_leadership']*5
# 1633*['cross-functional_team_leadership']*-1
# 1634*['team_building']*-1
# 1635*['mentoring']*-1
# 1636*['project_management']*2
# 1637*['business_analysis']*14
# 1638*['program_management']*22
# 1639*['vendor_management']*17
# 1640*['marketing']*-1
# 1641*['content_management']*-1
# 1642*['mobile_devices']*-1
# 1643*['agile_methodologies']*16
# 1644*['product_management']*-1
# 1645*['user_experience']*-1
# 1646*['telecommunications']*-1
# 1647*['technical_writing']*-1
# 1648*['content_strategy']*-1
# 1649*['budgets']*-1
# 1650*['account_management']*-1
# 1651*['editing']*-1
# 1652*['consulting']*-1
# 1653*['data_analysis']*-1
# 1654*['sharepoint']*-1
# 1655*['python']*-1
# 1656*['cross-functional_team_leadership']*-1
# 1657*['leadership']*7
# 1658*['customer_service']*11
# 1659*['software_defined_network']*-1
# 1660*['scrum']*18
# 1661*['pl/sql']*-1
# 1662*['power_bi']*-1
# 1663*['agile_methodologies']*16
# 1664*['project_management']*2
# 1665*['scrum']*18
# 1666*['business_analysis']*14
# 1667*['software_development_life_cycle_', 'sdlc']*-1
# 1668*['product_development']*-1
# 1669*['perl']*-1
# 1670*['sql']*1
# 1671*['oracle']*-1
# 1672*['microsoft_power_bi']*-1
# 1673*['microsoft_office']*3
# 1674*['team_building']*-1
# 1675*['sql_pl']*-1
# 1676*['vsts']*-1
# 1677*['rally']*-1
# 1678*['version_one']*-1
# 1679*['software_project_management']*13
# 1680*['project_management']*2
# 1681*['pmp']*-1
# 1682*['agile_project_management']*19
# 1683*['project_planning']*-1
# 1684*['business_analysis']*14
# 1685*['project_delivery']*-1
# 1686*['analysis']*-1
# 1687*['change_management']*6
# 1688*['business_requirements']*-1
# 1689*['requirements_gathering']*-1
# 1690*['requirements_analysis']*15
# 1691*['business_process']*12
# 1692*['business_process_mapping']*-1
# 1693*['business_process_improvement']*20
# 1694*['systems_analysis']*-1
# 1695*['user_acceptance_testing']*-1
# 1696*['pmo']*-1
# 1697*['service_delivery']*-1
# 1698*['risk_management']*-1
# 1699*['data_migration']*-1
# 1700*['general_insurance']*-1
# 1701*['insurance']*-1
# 1702*['event_management']*-1
# 1703*['it_service_management']*-1
# 1704*['it_operations']*-1
# 1705*['prince2']*-1
# 1706*['account_management']*-1
# 1707*['project_management']*2
# 1708*['leadership']*7
# 1709*['recruiting']*-1
# 1710*['publishing']*-1
# 1711*['content_marketing']*-1
# 1712*['technical_recruiting']*-1
# 1713*['contract_recruitment']*-1
# 1714*['executive_search']*-1
# 1715*['permanent_placement']*-1
# 1716*['start-ups']*-1
# 1717*['recruitment_advertising']*-1
# 1718*['business_analysis']*14
# 1719*['cloud_computing']*-1
# 1720*['business_development']*-1
# 1721*['consulting']*-1
# 1722*['python']*-1
# 1723*['java']*-1
# 1724*['ruby_on_rails']*-1
# 1725*['oracle']*-1
# 1726*['linux']*-1
# 1727*['sql']*1
# 1728*['html_5']*-1
# 1729*['amazon_web_services_', 'aws']*-1
# 1730*['ruby']*-1
# 1731*['ios']*-1
# 1732*['android']*-1
# 1733*['django']*-1
# 1734*['mongodb']*-1
# 1735*['objective-c']*-1
# 1736*['stakeholder_management']*-1
# 1737*['interviews']*-1
# 1738*['management']*10
# 1739*['team_leadership']*5
# 1740*['cocoa_touch']*-1
# 1741*['amazon_ec2']*-1
# 1742*['google_app_engine']*-1
# 1743*['redis']*-1
# 1744*['ventilation']*-1
# 1745*['air_conditioning']*-1
# 1746*['hvac']*-1
# 1747*['heating']*-1
# 1748*['plumbing']*-1
# 1749*['renewable_energy']*-1
# 1750*['boilers']*-1
# 1751*['contract_management']*-1
# 1752*['value_engineering']*-1
# 1753*['construction']*-1
# 1754*['procurement']*-1
# 1755*['natural_gas']*-1
# 1756*['drainage']*-1
# 1757*['building_services']*-1
# 1758*['engineering']*-1
# 1759*['construction_management']*-1
# 1760*['commercial_management']*-1
# 1761*['contract_negotiation']*-1
# 1762*['steam']*-1
# 1763*['biomass']*-1
# 1764*['chilled_water']*-1
# 1765*['central_heating']*-1
# 1766*['underfloor_heating']*-1
# 1767*['district_heating']*-1
# 1768*['compressed_air']*-1
# 1769*['chp']*-1
# 1770*['project_management']*2
# 1771*['six_sigma']*-1
# 1772*['strategic_planning']*-1
# 1773*['product_development']*-1
# 1774*['manufacturing']*-1
# 1775*['kaizen']*-1
# 1776*['toyota_production_system']*-1
# 1777*['process_improvement']*-1
# 1778*['5s']*-1
# 1779*['strategy']*-1
# 1780*['tqm']*-1
# 1781*['fmea']*-1
# 1782*['market_research']*-1
# 1783*['international_business']*-1
# 1784*['statistics']*-1
# 1785*['competitive_analysis']*-1
# 1786*['optimization']*-1
# 1787*['dmaic']*-1
# 1788*['pdca']*-1
# 1789*['international_project_management']*-1
# 1790*['emerging_markets']*-1
# 1791*['lean_sigma']*-1
# 1792*['problem_solving']*-1
# 1793*['7_qc_tools']*-1
# 1794*['7qc_tools']*-1
# 1795*['integration']*0
# 1796*['product_management']*-1
# 1797*['digital_asset_management']*-1
# 1798*['program_management']*22
# 1799*['streaming_media']*-1
# 1800*['digital_video']*-1
# 1801*['broadcast']*-1
# 1802*['solution_architecture']*-1
# 1803*['pre-sales']*-1
# 1804*['broadcast_television']*-1
# 1805*['product_development']*-1
# 1806*['software_development']*9
# 1807*['system_architecture']*-1
# 1808*['system_design']*-1
# 1809*['post_production']*-1
# 1810*['requirements_gathering']*-1
# 1811*['systems_engineering']*-1
# 1812*['user_interface_design']*-1
# 1813*['systems_design']*-1
# 1814*['analysis']*-1
# 1815*['content_management']*-1
# 1816*['integrated_marketing']*-1
# 1817*['software_engineering']*-1
# 1818*['iptv']*-1
# 1819*['linux']*-1
# 1820*['management']*10
# 1821*['broadcast_engineering']*-1
# 1822*['digital_tv']*-1
# 1823*['vod']*-1
# 1824*['satellite']*-1
# 1825*['fiber_optic_networks']*-1
# 1826*['telecommunications']*-1
# 1827*['training']*21
# 1828*['quality_assurance']*-1
# 1829*['project_management']*2
# 1830*['process_improvement']*-1
# 1831*['technical_writing']*-1
# 1832*['technical_analysis']*-1
# 1833*['troubleshooting']*-1
# 1834*['fiber_optics']*-1
# 1835*['benefits_negotiation']*-1
# 1836*['program_management']*22
# 1837*['network_design']*-1
# 1838*['business_process']*12
# 1839*['business_process_design']*-1
# 1840*['testing']*-1
# 1841*['software_documentation']*-1
# 1842*['integration']*0
# 1843*['crm']*-1
# 1844*['vendor_management']*17
# 1845*['consulting']*-1
# 1846*['analysis']*-1
# 1847*['sales']*-1
# 1848*['security']*-1
# 1849*['cisco_technologies']*-1
# 1850*['juniper']*-1
# 1851*['cisco_routers']*-1
# 1852*['enterprise_software']*-1
# 1853*['employee_training']*-1
# 1854*['leadership']*7
# 1855*['cross-functional_team_leadership']*-1
# 1856*['management']*10
# 1857*['veterans']*-1
# 1858*['networking']*-1
# 1859*['metrics']*-1
# 1860*['sdlc']*-1
# 1861*['visio']*-1
# 1862*['agile_methodologies']*16
# 1863*['integration']*0
# 1864*['business_analysis']*14
# 1865*['project_management']*2
# 1866*['program_management']*22
# 1867*['process_improvement']*-1
# 1868*['software_documentation']*-1
# 1869*['quality_assurance']*-1
# 1870*['vendor_management']*17
# 1871*['testing']*-1
# 1872*['web_development']*-1
# 1873*['start-ups']*-1
# 1874*['risk_management']*-1
# 1875*['pmo']*-1
# 1876*['technical_writing']*-1
# 1877*['requirements_analysis']*15
# 1878*['agile_project_management']*19
# 1879*['software_project_management']*13
# 1880*['seo']*-1
# 1881*['analysis']*-1
# 1882*['change_management']*6
# 1883*['pmp']*-1
# 1884*['project_planning']*-1
# 1885*['business_requirements']*-1
# 1886*['business_intelligence']*8
# 1887*['it_management']*-1
# 1888*['risk_mitigation']*-1
# 1889*['business_process_improvement']*20
# 1890*['scrum']*18
# 1891*['agile_', '_waterfall_methodologies']*-1
# 1892*['business_process']*12
# 1893*['project_managment']*-1
# 1894*['resource_management']*-1
# 1895*['ms_project']*-1
# 1896*['databases']*-1
# 1897*['microsoft_sql_server']*-1
# 1898*['sharepoint']*-1
# 1899*['sql']*1
# 1900*['access']*-1
# 1901*['mysql']*-1
# 1902*['windows']*-1
# 1903*['php']*-1
# 1904*['management']*10
# 1905*['leadership']*7
# 1906*['training']*21
# 1907*['team_leadership']*5
# 1908*['team_building']*-1
# 1909*['networking']*-1
# 1910*['project_management']*2
# 1911*['business_analysis']*14
# 1912*['quality_assurance']*-1
# 1913*['requirements_analysis']*15
# 1914*['project_planning']*-1
# 1915*['integration']*0
# 1916*['telecommunications']*-1
# 1917*['analysis']*-1
# 1918*['troubleshooting']*-1
# 1919*['software_documentation']*-1
# 1920*['crm']*-1
# 1921*['software_project_management']*13
# 1922*['six_sigma']*-1
# 1923*['software_development']*9
# 1924*['business_process_improvement']*20
# 1925*['security']*-1
# 1926*['business_process']*12
# 1927*['change_management']*6
# 1928*['project_delivery']*-1
# 1929*['scrum']*18
# 1930*['project_portfolio_management']*-1
# 1931*['program_management']*22
# 1932*['agile_methodologies']*16
# 1933*['test_planning']*-1
# 1934*['risk_management']*-1
# 1935*['erp']*-1
# 1936*['iso']*-1
# 1937*['quality_management']*-1
# 1938*['technical_writing']*-1
# 1939*['software_quality_assurance']*-1
# 1940*['cmmi']*-1
# 1941*['pmbok']*-1
# 1942*['ms_project']*-1
# 1943*['windows']*-1
# 1944*['visio']*-1
# 1945*['jira']*-1
# 1946*['team_leadership']*5
# 1947*['management']*10
# 1948*['team_management']*-1
# 1949*['leadership']*7
# 1950*['problem_solving']*-1
# 1951*['cross-functional_team_leadership']*-1
# 1952*['integration_testing']*-1
# 1953*['casino_gaming']*-1
# 1954*['gaming']*-1
# 1955*['software_project_management']*13
# 1956*['project_management']*2
# 1957*['requirements_analysis']*15
# 1958*['business_analysis']*14
# 1959*['requirements_gathering']*-1
# 1960*['e-learning']*-1
# 1961*['sdlc']*-1
# 1962*['agile_methodologies']*16
# 1963*['vendor_management']*17
# 1964*['agile_project_management']*19
# 1965*['program_management']*22
# 1966*['strategy']*-1
# 1967*['project_portfolio_management']*-1
# 1968*['testing']*-1
# 1969*['software_development']*9
# 1970*['project_planning']*-1
# 1971*['strategic_planning']*-1
# 1972*['content_management']*-1
# 1973*['customer_relations']*-1
# 1974*['blended_learning']*-1
# 1975*['data_analysis']*-1
# 1976*['flash']*-1
# 1977*['moodle']*-1
# 1978*['html5']*-1
# 1979*['microsoft_office']*3
# 1980*['educational_technology']*-1
# 1981*['team_management']*-1
# 1982*['team_leadership']*5
# 1983*['management']*10
# 1984*['leadership']*7
# 1985*['training']*21
# 1986*['critical_thinking']*-1
# 1987*['customer_service']*11
# 1988*['captivate']*-1
# 1989*['articulate_storyline']*-1
# 1990*['lectora']*-1
# 1991*['successfactors']*-1
# 1992*['social_learning']*-1
# 1993*['mobile_learning']*-1
# 1994*['needs_analysis']*-1
# 1995*['e-learning_consulting']*-1
# 1996*['onsite-offshore_co-ordination']*-1
# 1997*['onsite-offshore_delivery_model']*-1
# 1998*['articulate_suite']*-1
# 1999*['toolbook']*-1
# 2000*['traffic_management']*-1
# 2001*['long-term_customer_relationships']*-1
# 2002*['customer_loyalty']*-1
# 2003*['new_technology_evaluation']*-1
# 2004*['sumtotal']*-1
# 2005*['business_analysis']*14
# 2006*['software_project_management']*13
# 2007*['team_leadership']*5
# 2008*['integration']*0
# 2009*['project_management']*2
# 2010*['requirements_analysis']*15
# 2011*['software_development']*9
# 2012*['cmmi']*-1
# 2013*['quality_assurance']*-1
# 2014*['pmp']*-1
# 2015*['capability_maturity_model_integration_', 'cmmi']*-1
# 2016*['agile_methodologies']*16
# 2017*['pmo']*-1
# 2018*['strategic_planning']*-1
# 2019*['microsoft_project']*-1
# 2020*['quality_center']*-1
# 2021*['ms_project']*-1
# 2022*['uml']*-1
# 2023*['hp_quality_center']*-1
# 2024*['customer_service']*11
# 2025*['team_building']*-1
# 2026*['web_development']*-1
# 2027*['user_experience']*-1
# 2028*['cms']*-1
# 2029*['web_design']*-1
# 2030*['user_interface']*-1
# 2031*['usability']*-1
# 2032*['user_interface_design']*-1
# 2033*['start-ups']*-1
# 2034*['analytics']*-1
# 2035*['seo']*-1
# 2036*['video']*-1
# 2037*['web_applications']*-1
# 2038*['content_management']*-1
# 2039*['information_architecture']*-1
# 2040*['agile_methodologies']*16
# 2041*['e-commerce']*-1
# 2042*['web_analytics']*-1
# 2043*['dns']*-1
# 2044*['agile']*-1
# 2045*['javascript']*-1
# 2046*['css']*-1
# 2047*['cascading_style_sheets_', 'css']*-1
# 2048*['php']*-1
# 2049*['html']*4
# 2050*['mysql']*-1
# 2051*['wordpress']*-1
# 2052*['jquery']*-1
# 2053*['content_management_systems_', 'cms']*-1
# 2054*['databases']*-1
# 2055*['sql']*1
# 2056*['adobe_creative_suite']*-1
# 2057*['apache']*-1
# 2058*['dreamweaver']*-1
# 2059*['node.js']*-1
# 2060*['html_5']*-1
# 2061*['ajax']*-1
# 2062*['web_2.0']*-1
# 2063*['xml']*-1
# 2064*['google_analytics']*-1
# 2065*['linux']*-1
# 2066*['illustrator']*-1
# 2067*['xhtml']*-1
# 2068*['sql_server']*-1
# 2069*['management']*10
# 2070*['leadership']*7
# 2071*['webcasting']*-1
# 2072*['dhtml']*-1
# 2073*['coldfusion']*-1
# 2074*['front-end']*-1
# 2075*['hosting']*-1

# %% [markdown]
# # Analysis kills using Doc2Vec embedding

# %%
fpath= os.getcwd()
fprepath= os.path.join(fpath,"Preprocessing/")
file = open(os.path.join(fprepath,"jobSkillD2V_sep.p"),"rb")
JobSentenceEmb = pickle.load(file)

# %%
pmSentences= []
for jse in JobSentenceEmb:
    if jse[0].find("project manager or equivalent")!= -1 and jse[0].find("senior project manager or equivalent")== -1:
        pmSentences.append(jse[0:4])

jsenemb=[]
jsenskill=[]
for js in pmSentences:
    for tkn in js[3]:
        jsenemb.append(tkn)  
    for tk in js[2]:
        jsenskill.append(tk)

print ('Total Sentences: {}'.format(len(jsenemb)))
# Out:
# Total Sentences: 2076

# %%
minSamples=[12]#[6,12,50,120]
eps = [0.1,0.5,0.75]#[0.75]#[0.80,0.81]#[0.3,0.5,0.75]

jsenemb = np.asarray(jsenemb)
mets = ['cosine','canberra','hamming']#'euclidean'#'cosine'
# #############################################################################
# Compute DBSCAN
for met in mets:
    print('Metric: %s' %met)
    for ep in eps:
        print('Eps: {}'.format(ep))
        for minsample in minSamples:
            dbscan_model = DBSCAN(eps=ep, min_samples=minsample,metric=met)
            x = dbscan_model.fit(jsenemb)
            core_samples_mask = np.zeros_like(dbscan_model.labels_, dtype=bool)
            core_samples_mask[dbscan_model.core_sample_indices_] = True
            labels = dbscan_model.labels_

        # Number of clusters in labels, ignoring noise if present.
            n_clusters_ = len(set(labels)) - (1 if -1 in labels else 0)
            n_noise_ = list(labels).count(-1)

            print('Min Samples: {}'.format(minsample))
            print('Estimated number of clusters: %d' % n_clusters_)
            print('Estimated number of noise points: %d' % n_noise_)
            
            #Calculation of Principal Component analysis
            pca = PCA(n_components=2).fit(jsenemb)
            datapoint = pca.transform(jsenemb)

            # Plot result
            # Black removed and is used for noise instead.
            unique_labels = set(labels)
            colors = [plt.cm.Spectral(each)
                      for each in np.linspace(0, 1, len(unique_labels))]
            print(len(colors))
            for k, col in zip(unique_labels, colors):
                if k == -1:
                    # Black used for noise.
                    col = [0, 0, 0, 1]

                class_member_mask = (labels == k)

                xy = datapoint[class_member_mask & core_samples_mask]
                plt.plot(xy[:, 0], xy[:, 1], 'o', markerfacecolor=tuple(col),
                         markeredgecolor='k', markersize=12)

                xy = datapoint[class_member_mask & ~core_samples_mask]
                plt.plot(xy[:, 0], xy[:, 1], '.', markerfacecolor=tuple(col),
                         markeredgecolor='k', markersize=2)

#             plt.margins(x=0, y=-0.45)   # Values in (-0.5, 0.0) zooms in to center

            plt.title('Estimated number of clusters: {} - {} - {} eps'.format(n_clusters_,met, ep))
            plt.show()
# Out:
# Metric: cosine
# Eps: 0.1
# Min Samples: 12
# Estimated number of clusters: 32
# Estimated number of noise points: 508
# 33
# Eps: 0.5
# Min Samples: 12
# Estimated number of clusters: 1
# Estimated number of noise points: 0
# 1
# Eps: 0.75
# Min Samples: 12
# Estimated number of clusters: 1
# Estimated number of noise points: 0
# 1
# Metric: canberra
# Eps: 0.1
# Min Samples: 12
# Estimated number of clusters: 23
# Estimated number of noise points: 1659
# 24
# Eps: 0.5
# Min Samples: 12
# Estimated number of clusters: 23
# Estimated number of noise points: 1659
# 24
# Eps: 0.75
# Min Samples: 12
# Estimated number of clusters: 23
# Estimated number of noise points: 1659
# 24
# Metric: hamming
# Eps: 0.1
# Min Samples: 12
# Estimated number of clusters: 23
# Estimated number of noise points: 1659
# 24
# Eps: 0.5
# Min Samples: 12
# Estimated number of clusters: 23
# Estimated number of noise points: 1659
# 24
# Eps: 0.75
# Min Samples: 12
# Estimated number of clusters: 23
# Estimated number of noise points: 1659
# 24
